# %%
using Curiosity, Statistics, Plots, FileIO, BSON
using Random, StatsBase, RollingFunctions

# %%
# Cumulant
struct Reward end

(c::Reward)(;kwargs...) = kwargs[:r]

struct ConstantDiscount{F}
    val::F
end
   
(d::ConstantDiscount)(;kwargs...) = d.val

# %%
# Policy learning struct
mutable struct PolicyLearner{L<:Curiosity.Learner, FC, E, D, C, Φ}
    learner::L
    fc::FC
    exploration::E
    
    discount::D
    cumulant::C
    o_t::Φ
    a_t::Int
end

function Curiosity.start!(pl::PolicyLearner, o)
    s_t = pl.fc(o)
    pl.o_t = copy(o)
    pl.a_t = μ(pl, s_t)
    
    pl.a_t
end

function μ_dist(pl::PolicyLearner, state)
    qs = agent.learner(state)
    agent.exploration(qs)
end

function μ(pl::PolicyLearner, state)
    action_probs = μ_dist(pl, state)
    action = sample(1:length(action_probs), Weights(action_probs))
end

function Curiosity.step!(pl::PolicyLearner, o_tp1, rew, term)
    s_tp1 = pl.fc(o_tp1)
    next_action = μ(pl, s_tp1)
    
    rew = pl.cumulant(;r=rew, o_t=pl.o_t, a_t=pl.a_t, o_tp1=o_tp1)
    γ = if pl.discount isa Number
        pl.discount
    else
        pl.discount(;r=rew, o_t=pl.o_t, a_t=pl.a_t, o_tp1=o_tp1)
    end
    
    update!(
            agent.learner,
            nothing,
            pl.o_t,
            o_tp1,
            pl.fc(pl.o_t),
            pl.a_t,
            s_tp1,
            next_action,
            term,
            [rew],
            [γ],
            (state, obs) -> μ_dist(pl, state))
    
    pl.o_t = copy(o_tp1)
    pl.a_t = next_action
    
    pl.a_t
end

# %%
# Environment 
function construct_env()
    normalized = true
    env = MountainCar(0.0, 0.0, normalized)
end
# Out:
# construct_env (generic function with 1 method)

# %%
# Agent
function construct_agent(numtilings, numtiles, lu_str, α, λ, ϵ, γ)
    obs_size = 2
    fc = Curiosity.SparseTileCoder(numtilings, numtiles, obs_size)
    feature_size = size(fc)

    lu = if lu_str == "ESARSA"
        ESARSA(lambda=λ, opt=Curiosity.Descent(α))
    elseif lu_str == "SARSA"
        SARSA(lambda=λ, opt=Curiosity.Descent(α))
    elseif lu_str == "TB"
        TB(lambda=λ, opt=Curiosity.Descent(α))
    else
        throw(ArgumentError("$(lu_str) Not a valid behaviour learning update"))
    end
    learner = LinearQLearner(lu, feature_size, 3, 1)
    exploration = EpsilonGreedy(ϵ)
    cumulant = Reward()
    discount = ConstantDiscount(γ)

    agent = PolicyLearner(learner, 
                          fc, 
                          exploration, 
                          discount, 
                          cumulant, 
                          zeros(2), 
                          0)
end
# Out:
# construct_agent (generic function with 1 method)

# %%
# Learn the policy
seed = 1029
Random.seed!(seed)
numtilings, numtiles = 8, 8
lu_str = "ESARSA"
α = 0.1/numtilings
λ = 0.9
ϵ = 0.1
γ = 0.99

info = Dict(
    "seed"=>seed,
    "numtilings"=>numtilings,
    "numtiles"=>numtiles,
    "lu"=>"lu_str",
    "α"=>α,
    "λ"=>λ,
    "ϵ"=>ϵ,
    "γ"=>γ,
    "rew"=>"Env"
)


env = construct_env()
agent = construct_agent(numtilings, numtiles, lu_str, α, λ, ϵ, γ)

steps = Int[]
ret = Float64[]
max_num_steps = 100000
eps = 0
while sum(steps) < max_num_steps
    is_terminal = false

    max_episode_steps = min(max_num_steps - sum(steps), 1000)
    s = start!(env)
    a = start!(agent, s)
    stp = 0
    a = 0
    tr = 0.0
    while !is_terminal && stp <= max_episode_steps
        s, r, is_terminal = MinimalRLCore.step!(env, a)
        a = step!(agent, s, r, is_terminal)
        tr += r
        stp += 1
    end

    push!(steps, stp)
    push!(ret, tr)
    
    eps += 1
end
# Out:
# MethodError: no method matching Dict(::Pair{String,Int64}, ::Pair{String,Int64}, ::Pair{String,Int64}, ::Pair{String,String}, ::Pair{String,Float64}, ::Pair{String,Float64}, ::Pair{String,Float64}, ::typeof(\))
# Closest candidates are:
#   Dict(!Matched::Pair{K,V}...) where {K, V} at dict.jl:123
#   Dict(!Matched::Pair...) at dict.jl:124
#   Dict(::Any) at dict.jl:126
#
# Stacktrace:
#  [1] top-level scope at In[77]:11
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [3] execute_code(::String, ::String) at /Users/Matt/.julia/packages/IJulia/a1SNk/src/execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/Matt/.julia/packages/IJulia/a1SNk/src/execute_request.jl:86
#  [5] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [6] invokelatest at ./essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at /Users/Matt/.julia/packages/IJulia/a1SNk/src/eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
plot(rollmean(ret, 100))

# %%
# Save the policy

# %%
save("policy.bson", Dict("learner"=>agent.learner, "fc"=>agent.fc, "exp"=>agent.exploration))
